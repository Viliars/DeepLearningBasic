# %%
import random
import matplotlib.pyplot as plt
import numpy as np
import torch
import os

from data_loader import *
from model import *
from train import *

random.seed(0)
np.random.seed(0)
torch.manual_seed(0)

# %%
f = open("./experiment/train_losses.txt")
a = list(map(float, f.read().strip().split(" ")))
f.close()

# %%
f = open("./experiment/test_losses.txt")
b = list(map(float, f.read().strip().split(" ")))
f.close()

# %%
plt.plot(a, label="train")
plt.plot(b, label="test")
plt.ylabel('Loss function')
plt.legend()
plt.show()

# %%
f = open("./experiment/train_cers.txt")
a = list(map(float, f.read().strip().split(" ")))
f.close()

# %%
f = open("./experiment/test_cers.txt")
b = list(map(float, f.read().strip().split(" ")))
f.close()

# %%
plt.plot(a, label="train")
plt.plot(b, label="test")
plt.ylabel('CER')
plt.legend()
plt.show()
